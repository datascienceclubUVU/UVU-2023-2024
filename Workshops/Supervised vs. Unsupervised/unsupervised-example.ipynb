# %% [markdown]
# # **Unsupervised Model Example**
# #### **Description**: In this example, we will be using a dataset of over 1 Million songs extracted from Spotify. Each row contains various metrics about the song, some created by Spotify's Audio Analysis engine, others extracted from the track itself. Our goal will be to cluster the songs to identify common genres.
# ##### **NOTE:** The K-Means algorithm is biased against Categorical Features, thus we'll remove those features.

# %% [markdown]
# ### **Step 1. Import Required Libraries**

# %%
# data wrangling libraries
import pandas as pd
# model fit libraries
from sklearn.cluster import KMeans

# %% [markdown]
# ### **Step 2. Preview Training Data and Schema**
# ##### Whenever you're unfamiliar with your data in the slightest, it's wise to analyze the schema and understand how all the features may relate to each other.

# %%
training_data = pd.read_parquet('clean_songs_dataset.parquet')
training_data.reset_index(drop=True, inplace=True)
training_data
# Out:
#                                            track_name        artist1
# 0                                           Sk8er Boi  Avril Lavigne  \
# 1                                           Paparazzi      Lady Gaga
# 2                                               Sorry  Justin Bieber
# 3                                                 S&M        Rihanna
# 4                                        Shake It Off   Taylor Swift
# ...                                               ...            ...
# 1157476                                    Wrong Move    Olivia Holt
# 1157477                 Howl At The Moon - Radio Edit       Stadiumx
# 1157478  Let The Bass Kick In Miami Girl - Radio Edit        Chuckie
# 1157479                                   You Make Me         Avicii
# 1157480                                      Dynamite       AFROJACK
#
#              artist2   artist3 artist4 artist5
# 0               None      None    None    None  \
# 1               None      None    None    None
# 2               None      None    None    None
# 3               None      None    None    None
# 4               None      None    None    None
# ...              ...       ...     ...     ...
# 1157476        R3HAB  THRDL!FE    None    None
# 1157477  Taylr Renee      None    None    None
# 1157478        LMFAO      None    None    None
# 1157479         None      None    None    None
# 1157480   Snoop Dogg      None    None    None
#
#                                album_name release_date  danceability  energy
# 0                                  Let Go   2002-06-04         0.487   0.900  \
# 1                                The Fame   2008-01-01         0.762   0.692
# 2                        Purpose (Deluxe)   2015-11-13         0.654   0.760
# 3                                    Loud   2010-11-16         0.767   0.682
# 4                           1989 (Deluxe)   2014-01-01         0.647   0.800
# ...                                   ...          ...           ...     ...
# 1157476                          The Wave   2018-08-25         0.722   0.706
# 1157477  Nicky Romero presents Miami 2014   2014-03-17         0.514   0.934
# 1157478   Let The Bass Kick In Miami Girl   2009-12-06         0.762   0.937
# 1157479              True (Bonus Edition)   2013-09-16         0.586   0.727
# 1157480         Forget The World (Deluxe)   2014-01-01         0.550   0.812
#
#          track_popularity  acousticness  valence    tempo
# 0                    73.0      0.000068    0.484  149.937
# 1                    70.0      0.113000    0.397  114.906
# 2                    78.0      0.079700    0.410   99.945
# 3                    70.0      0.011300    0.833  127.975
# 4                    78.0      0.064700    0.942  160.078
# ...                   ...           ...      ...      ...
# 1157476               0.0      0.161000    0.517  124.013
# 1157477              28.0      0.052500    0.182  127.953
# 1157478               0.0      0.050400    0.546  128.021
# 1157479              51.0      0.002470    0.496  124.989
# 1157480              32.0      0.017300    0.203  145.037
#
# [1157481 rows x 14 columns]

# %%
with open("clean_songs_dataset_schema.txt", "r") as file:
    for line in file:
        print(line)
# Out:
# TRAINING DATA SCHEMA
#
#
#
# track_name - name of the song.
#
# artist1 - first artist featured on the song.
#
# artist2 - second artist featured on the song.
#
# artist3 - third artist featured on the song.
#
# artist4 - fourth artist featured on the song.
#
# artist5 - fifth artist featured on the song.
#
# album_name - name of the album the song is on.
#
# release_date - date the song was released on Spotify.
#
# danceability - metric measuring how groovy a song is (1.0 means 70s Disco-level groovy, 0.0 means Beethoven-level groovy).
#
# energy - metric measuring how epic the song is (1.0 means 2011 Skrillex, 0.0 means Frank Ocean).
#
# track_popularity - metric measuring how popular the song is based off number of streams, song downloads, and other factors (100.0 means Shape of You by Ed Sheeran, 0.0 means Late 1960s Queen).
#
# acousticness - proobability of a given song being acoustic (1.0 means it is acoustic, 0.0 means it isn't).
#
# valence - metric measuring how positive or negative the vibes are (1.0 means Pharrell Williams, 0.0 means Linkin Park).
#
# tempo - bpm of the song.

# %% [markdown]
# ### **Step 3. Perform Feature Engineering**
# ##### As mentioned above, we will need to remove Categorical Features as they will create Bias in the model.

# %%
training_data.drop(columns=['track_name', 'artist1', 'artist2', 'artist3', 'artist4', 'artist5', 'album_name', 'release_date'], inplace=True)
training_data
# Out:
#          danceability  energy  track_popularity  acousticness  valence
# 0               0.487   0.900              73.0      0.000068    0.484  \
# 1               0.762   0.692              70.0      0.113000    0.397
# 2               0.654   0.760              78.0      0.079700    0.410
# 3               0.767   0.682              70.0      0.011300    0.833
# 4               0.647   0.800              78.0      0.064700    0.942
# ...               ...     ...               ...           ...      ...
# 1157476         0.722   0.706               0.0      0.161000    0.517
# 1157477         0.514   0.934              28.0      0.052500    0.182
# 1157478         0.762   0.937               0.0      0.050400    0.546
# 1157479         0.586   0.727              51.0      0.002470    0.496
# 1157480         0.550   0.812              32.0      0.017300    0.203
#
#            tempo
# 0        149.937
# 1        114.906
# 2         99.945
# 3        127.975
# 4        160.078
# ...          ...
# 1157476  124.013
# 1157477  127.953
# 1157478  128.021
# 1157479  124.989
# 1157480  145.037
#
# [1157481 rows x 6 columns]

# %% [markdown]
# ### **Step 4. Fit Training Data to Model**
# ##### When Using the K-Means Algorhtm, you'll need to specify the number of clusters (the "K" in K-Means). This is typically chosen using either an Elbow or Silouhette Chart. In this case, we'll randomly choose 10 clusters.

# %%
model = KMeans(n_clusters=10).fit(training_data)
pd.DataFrame(model.cluster_centers_, columns=['danceability', 'energy', 'track_popularity', 'acousticness', 'valence', 'tempo'])
# Out:
#    danceability    energy  track_popularity  acousticness   valence
# 0      0.580598  0.639906         10.369624      0.285435  0.502879  \
# 1      0.652142  0.628147         49.416058      0.288513  0.494944
# 2      0.493723  0.632415         17.195867      0.317653  0.526726
# 3      0.636806  0.596579         27.620017      0.352649  0.517629
# 4      0.502312  0.428527         27.311075      0.543599  0.383032
# 5      0.607107  0.569559         48.547577      0.363743  0.484270
# 6      0.632768  0.630118         28.646338      0.291148  0.480497
# 7      0.655571  0.631645          6.318527      0.290648  0.510002
# 8      0.548603  0.664789         41.584333      0.263371  0.510874
# 9      0.590108  0.544861          5.857219      0.411923  0.493597
#
#         tempo
# 0  147.857206
# 1  126.205565
# 2  180.004867
# 3  104.227272
# 4   77.229635
# 5   91.327281
# 6  130.120818
# 7  122.123736
# 8  161.753434
# 9   89.962063
